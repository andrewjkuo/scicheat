# %%
import pandas as pd
from scicheat.dataloader import PrimaryAnalysis

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/heart/heart.dat'
names = ['age', 'sex', 'pain_type', 'rest_bp', 'serum_chol', 'fast_bl_sugar',
         'rest_ec_val', 'max_hr', 'exercise_angina', 'oldpeak', 'peak_slope',
         'num_of_maj_vessels', 'thal', 'heart_disease_presence']

df = pd.read_csv(data_url, names=names, sep=' ')
df.head()
# Out:
#     age  sex  pain_type  rest_bp  serum_chol  fast_bl_sugar  rest_ec_val  \
# 0  70.0  1.0        4.0    130.0       322.0            0.0          2.0
# 1  67.0  0.0        3.0    115.0       564.0            0.0          2.0
# 2  57.0  1.0        2.0    124.0       261.0            0.0          0.0
# 3  64.0  1.0        4.0    128.0       263.0            0.0          0.0
# 4  74.0  0.0        2.0    120.0       269.0            0.0          2.0
#
#    max_hr  exercise_angina  oldpeak  peak_slope  num_of_maj_vessels  thal  \
# 0   109.0              0.0      2.4         2.0                 3.0   3.0
# 1   160.0              0.0      1.6         2.0                 0.0   7.0
# 2   141.0              0.0      0.3         1.0                 0.0   7.0
# 3   105.0              1.0      0.2         2.0                 1.0   7.0
# 4   121.0              1.0      0.2         1.0                 1.0   3.0
#
#    heart_disease_presence
# 0                       2
# 1                       1
# ...

# %%
pa = PrimaryAnalysis(df=df, target='heart_disease_presence')
pa.run_all()
# Out:
# ----------------------------------------------------------------------------------------------------
# UNIVARIATE ANALYSIS
# ----------------------------------------------------------------------------------------------------
# BIVARIATE ANALYSIS
# ----------------------------------------------------------------------------------------------------
# LINEAR MODEL
#
# Accuracy: 0.853
#
# AUC: 0.922
# ----------------------------------------------------------------------------------------------------
# RANDOM FOREST MODEL
#
# Accuracy: 0.824
#
# AUC: 0.898
# ----------------------------------------------------------------------------------------------------
# Columns Used:
# 	 age
# 	 sex
# 	 pain_type
# 	 rest_bp
# 	 serum_chol
# 	 fast_bl_sugar
# 	 rest_ec_val
# 	 max_hr
# 	 exercise_angina
# 	 oldpeak
# 	 peak_slope
# 	 num_of_maj_vessels
# 	 thal
# 	 heart_disease_presence
# Ignored Columns:
# ...
